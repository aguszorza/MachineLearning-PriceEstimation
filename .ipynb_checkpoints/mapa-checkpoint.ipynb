# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Polygon, MultiPolygon, Point
import pandas as pd
from matplotlib import pyplot as plt
from shapely import wkt
from geopandas import GeoDataFrame

# %%
CABA = gpd.read_file('datos/mapas/barrios.shp')
CABA.head()
# Out:
#              BARRIO  COMUNA    PERIMETRO          AREA  \
# 0         CHACARITA    15.0  7725.695228  3.118101e+06
# 1          PATERNAL    15.0  7087.513295  2.229829e+06
# 2      VILLA CRESPO    15.0  8132.699348  3.613584e+06
# 3  VILLA DEL PARQUE    11.0  7705.389797  3.399596e+06
# 4           ALMAGRO     5.0  8537.901368  4.050752e+06
#
#                                             geometry
# 0  POLYGON ((-58.4528200492791 -34.5959886570639,...
# 1  POLYGON ((-58.4655768128541 -34.5965577078058,...
# 2  POLYGON ((-58.4237529813037 -34.5978273383243,...
# 3  POLYGON ((-58.4946097568899 -34.6148652395239,...
# 4  POLYGON ((-58.4128700313089 -34.6141162515854,...

# %%
# La mantengo por las dudas pero no  creo que sea necesaria

def obtener_poligono(multi):
    l =[]
    for x in multi.split(')'):
        poligono = []
        for y in x.split(','):
            if 'MULTIPOLYGON ' in y:
                y = y.replace('MULTIPOLYGON ', '')
            if 'POLYGON ' in y:
                y = y.replace('POLYGON ', '')
            if '(' in y:
                y = y.replace('(', '')
            if len(y) < 5:
                continue
            lon, lat = y.split()
            poligono.append((float(lon), float(lat)))
        l.append(Polygon(poligono))
    return MultiPolygon(l)

# %%
#CABA.loc[:,'geometry'] = CABA.loc[:,'geometry'].apply(lambda x: obtener_poligono(x))

# %%
#CABA.head()
# Out:
#                                             geometry            BARRIO  \
# 0  (POLYGON ((-58.4528200492791 -34.5959886570639...         CHACARITA
# 1  (POLYGON ((-58.4655768128541 -34.5965577078058...          PATERNAL
# 2  (POLYGON ((-58.4237529813037 -34.5978273383243...      VILLA CRESPO
# 3  (POLYGON ((-58.4946097568899 -34.6148652395239...  VILLA DEL PARQUE
# 4  (POLYGON ((-58.4128700313089 -34.6141162515854...           ALMAGRO
#
#    COMUNA    PERIMETRO          AREA
# 0    15.0  7725.695228  3.118101e+06
# 1    15.0  7087.513295  2.229829e+06
# 2    15.0  8132.699348  3.613584e+06
# 3    11.0  7705.389797  3.399596e+06
# 4     5.0  8537.901368  4.050752e+06

# %%
#geoData = GeoDataFrame(CABA)
#geoData.plot(color='white', edgecolor='black',figsize=(10,10))
CABA.plot(color='white', edgecolor='black',figsize=(10,10))
plt.show()

# %%
subtes = gpd.read_file('datos/mapas/subtes.shp')
subtes.head()
# Out:
#            X          Y   ID                ESTACION LINEA  \
# 0 -58.398928 -34.635750  1.0                 CASEROS     H
# 1 -58.400970 -34.629376  2.0                  INCLAN     H
# 2 -58.402323 -34.623092  3.0              HUMBERTO 1     H
# 3 -58.404732 -34.615242  4.0               VENEZUELA     H
# 4 -58.406036 -34.608935  5.0  ONCE - 30 DE DICIEMBRE     H
#
#                                        geometry
# 0    POINT (-58.3989275853601 -34.635750180343)
# 1  POINT (-58.40096955601651 -34.6293756575728)
# 2    POINT (-58.402322730424 -34.6230923205019)
# 3  POINT (-58.40473171649001 -34.6152421522706)
# 4  POINT (-58.40603638103521 -34.6089352416216)

# %%
A = subtes.loc[subtes.LINEA == 'A',:]
B = subtes.loc[subtes.LINEA == 'B',:]
C = subtes.loc[subtes.LINEA == 'C',:]
D = subtes.loc[subtes.LINEA == 'D',:]
E = subtes.loc[subtes.LINEA == 'E',:]
H = subtes.loc[subtes.LINEA == 'H',:]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set_aspect('equal')

CABA.plot(ax=ax, color='white', edgecolor='black')

A.plot(ax=ax, color='cyan', markersize=15)
B.plot(ax=ax, color='red', markersize=15)
C.plot(ax=ax, color='blue', markersize=15)
D.plot(ax=ax, color='darkgreen', markersize=15)
E.plot(ax=ax, color='purple', markersize=15)
H.plot(ax=ax, color='gold', markersize=15)

plt.show();

# %%
geoData.contains(Point(-58.516100,-34.589408)).any()
# Out:
# True

# %%
geoData.contains(Point(58.516100,-34.589408)).any()
# Out:
# False
